# %% [markdown]
# # Integrated Gradients Demo Notebook
#
# This notebook demonstrates the usage of Integrated Gradients for explainable AI.
#
# ## ⚠️ Disclaimer
# This demo is for research and educational purposes only. XAI outputs may be unstable or misleading and should not be used as a substitute for human judgment in regulated decisions.
